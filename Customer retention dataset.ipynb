# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_excel('C:\\Users\\hp\\Desktop\\customer_retention_dataset.xlsx') #Importing Dataset

# %%
df=pd.DataFrame(ds)
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# 269 rows and 71 columns

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# No null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# Datatype is object type

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
1.# Comparing Gender and age group:
g=sns.histplot(x="1Gender of respondent",y="2 How old are you? " ,data=df)
plt.show()

# %% [markdown]
# Number of active users are in the age group 21 to 50 years and maximum of them are females.
# majorly age group of 21-30 years female gender are active on e-commerce platform.

# %%
2. # Comparing Years of using online platform and age number of times products purchased:
g=sns.histplot(x='5 Since How Long You are Shopping Online ?',y='6 How many times you have made an online purchase in the past 1 year?' ,data=df)
plt.show()

# %% [markdown]
# Maximum ppl are using ecommerce sites for above 4 years and have shopped from there at less than 10 times, 31 to 40 times and 41 times & above.
# Ppl who have shopped for less than 10 times are also using ecommerce sites since 2-3 years and less than 1 year.

# %%
3. # Comparing gender and device used for shopping:
g=sns.histplot(x='1Gender of respondent',y='8 Which device do you use to access the online shopping?' ,data=df)
plt.show()

# %% [markdown]
# Maximum females use smartphones and after that laptop .
# Males are also using smartphones but ratio is less as compered to females.
# smartphones users are more

# %%
4. # Comparing device used and age group
g=sns.histplot(x="8 Which device do you use to access the online shopping?",y="2 How old are you? ",data=df)
plt.show()

# %% [markdown]
# Smartphone users are maximum and age group of 21-30 years uses it the max.

# %%
5. # Comparing age and ease of navigating in websites
g=sns.histplot(x='2 How old are you? ',y='22 Ease of navigation in website',data=df)
plt.show()

# %% [markdown]
# Maximum ppl agree and strongly agree that ease of navigating website is important
# Age group of 21-30 years,31-40 years and 41-40 years strongly agree for website navigating ease and mostly by 31-40 years age group.

# %%
g=sns.histplot(x='2 How old are you? ',y='27 Empathy (readiness to assist with queries) towards the customers',data=df)
plt.show()

# %% [markdown]
# Age group of 21-40 years strongly agrees for empathy towards the customer

# %%
g=sns.histplot(x='2 How old are you? ',y='28 Being able to guarantee the privacy of the customer',data=df)
plt.show()

# %% [markdown]
# Age group of 21-40 years strongly agrees for guarantee of customer's privacy

# %%
g=sns.histplot(x='2 How old are you? ',y='39 Offering a wide variety of listed product in several category',data=df)
plt.show()

# %% [markdown]
# Age group of 21-50 years agrees for Offering a wide variety of listed product in several category

# %%
g=sns.histplot(x='2 How old are you? ',y='40 Provision of complete and relevant product information',data=df)
plt.show()

# %% [markdown]
# Majorly age group of 41-50years looks for the complete and relevant product information

# %%
g=sns.histplot(x='2 How old are you? ',y='41 Monetary savings',data=df)
plt.show()

# %% [markdown]
# 21-30 years and 41-50 years age group strongly agrees for monetary savings

# %%
g=sns.histplot(y="2 How old are you? ",x="42 The Convenience of patronizing the online retailer",data=df)
plt.show()

# %% [markdown]
# 21-30 years and 31-40 years age group agrees for The Convenience of patronizing the online retailer

# %%
g=sns.histplot(x='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',y="2 How old are you? ",data=df)
plt.show()

# %% [markdown]
# Maximum 21-50 years uses search engine for ecommerce webiste

# %%
g=sns.histplot(x='43 Shopping on the website gives you the sense of adventure',y="2 How old are you? ",data=df)
plt.show()

# %% [markdown]
# 31-40 years largely agrees to feel the sense of adventure during online shopping

# %%
g=sns.histplot(x="2 How old are you? ",y='44 Shopping on your preferred e-tailer enhances your social status',data=df)
plt.show()

# %% [markdown]
# Only 21-30 years of age group feels that shopping on preferred website enhances social status and 31-40 years & 41-50 years feels neutral about social status being raised by shopping online.

# %%
g=sns.histplot(x="2 How old are you? ",y='45 You feel gratification shopping on your favorite e-tailer',data=df)
plt.show()

# %% [markdown]
# 21-30 years age group agrees for feeling gratified on shopping from favourite e-tailer also feels neutral about it
# age group of 31-40 years feels neutral about feeling gratified on shopping from favourite e-tailer

# %%
g=sns.histplot(x="2 How old are you? ",y='46 Shopping on the website helps you fulfill certain roles',data=df)
plt.show()

# %% [markdown]
# 21-30 years age group feels neutral for Shopping on the website helps fulfill certain roles but age group of 31-40 years agrees that Shopping on the website helps fulfill certain roles

# %%
g=sns.histplot(x="2 How old are you? ",y='47 Getting value for money spent',data=df)
plt.show()

# %% [markdown]
# Majorly age group of 21-30 years and 41-50 years agrees to feels they are getting value for money spent on e-tailers

# %%
g=sns.histplot(x="2 How old are you? ",y='Easy to use website or application',data=df)
plt.show()

# %% [markdown]
# 31-40 years maximumly use All the platforms and then 21-30 years uses all the e-tailer

# %%
g=sns.histplot(x="2 How old are you? ",y='Which of the Indian online retailer would you recommend to a friend?',data=df)
plt.show()

# %% [markdown]
# 31-40 years recommends Flipkart maximumly
# 21-30 years majorly refers Amazon and Flipkart
# 41-50 years refers Amazon website strongly

# %%
g=sns.histplot(x="2 How old are you? ",y='Security of customer financial information',data=df)
plt.show()

# %% [markdown]
# Customers finds their financial information is secure more in Amazon, Flipkart, Paytm, Myntra and Snapdeal by 31-40 years.

# %%
g=sns.histplot(x="2 How old are you? ",y='Perceived Trustworthiness',data=df)
plt.show()

# %% [markdown]
# 21-30 years and 41-50 years age group finds Amazon.com most trustworthy

# %% [markdown]
# Maximum 21-30 , 31-40 and 41-50 years are active in ecommerce websites and the maximum users are Females
#  Ppl prefer smartphones and laptops for using e-tailers site using search engines majorly.
#  Maximum ppl from 21-30 and 41 -50 years age group have max trust on Amazon website

# %% [markdown]
# ## Encoding:

# %%
# Converting string data to int using label encoder:
from sklearn.preprocessing import LabelEncoder
en= LabelEncoder()
df=df.apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      1                    1
# 1                      0                    0
# 2                      0                    0
# 3                      1                    0
# 4                      0                    0
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                                  1
# 1                                                  5
# 2                                                 23
# 3                                                 11
# 4                                                 31
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           3
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   int64
# 2 How old are you?                                                      int64
# 3 Which city do you shop online from?                                   int64
# 4 What is the Pin Code of where you shop online from?                   int64
# 5 Since How Long You are Shopping Online ?                              int64
#                                                                         ...
# Longer delivery period                                                  int64
# Change in website/Application design                                    int64
# Frequent disruption when moving from one page to another                int64
# Website is as efficient as before                                       int64
# Which of the Indian online retailer would you recommend to a friend?    int64
# Length: 71, dtype: object

# %% [markdown]
# String data changed to int

# %%
df.skew()
# Out:
# 1Gender of respondent                                                   0.741028
# 2 How old are you?                                                      0.680987
# 3 Which city do you shop online from?                                   0.313729
# 4 What is the Pin Code of where you shop online from?                   0.114537
# 5 Since How Long You are Shopping Online ?                             -0.276968
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64

# %% [markdown]
# Skewness range is between +/- 0.5, all the values are under permissable range so need not to treat skewness.

# %%
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.327138             1.330855
# std                 0.470042             1.183774
# min                 0.000000             0.000000
# 25%                 0.000000             0.000000
# 50%                 0.000000             1.000000
# 75%                 1.000000             2.000000
# max                 1.000000             4.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %% [markdown]
# Key Observations:
#     1. mean and median are having small differences.
#     2. 75% and max are doesnt have much difference so less outliers present.

# %%
plt.figure(figsize=(50,50))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="Blue",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Final Findings:
# 1. Females are majorly active on online shopping sites as compare to males  and they prefer search engines and smartphones for shopping online.
# 2. Retention on e-retail depends upon Hedonics and utilitarian values and also on trust worthiness of the website
# 3. From the survey it shows people majorly of 21-30 and 31-40 years are active and prefer Amazon.com and Flipkart.com for shopping online as it gives them sense of adventure, monetary benefits and many more.
